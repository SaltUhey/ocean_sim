# %%
#https://arlpy.readthedocs.io/en/latest/_static/bellhop.html

# %%
import arlpy.uwapm as pm
print(pm.models())
# Out:
# ['bellhop']

# %%
env = pm.create_env2d()
pm.print_env(env)
# Out:
#                 name : arlpy
#    bottom_absorption : 0.1
#       bottom_density : 1600
#     bottom_roughness : 0
#    bottom_soundspeed : 1600
#                depth : 25
#         depth_interp : linear
#            frequency : 25000
#            max_angle : 80
#            min_angle : -80
#               nbeams : 0
#             rx_depth : 10
#             rx_range : 1000
#           soundspeed : 1500
#    soundspeed_interp : spline
#              surface : None
#       surface_interp : linear
#             tx_depth : 5
#    tx_directionality : None
#                 type : 2D

# %%
pm.plot_env(env, width=900)
# Out:
# BokehDeprecationWarning: 'asterisk() method' was deprecated in Bokeh 3.4.0 and will be removed, use "scatter(marker='asterisk', ...) instead" instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="e21d1147-e42d-413c-8923-cbb29effa482" data-root-id="p2824" style="display: contents;"></div>

# %%
rays = pm.compute_eigenrays(env)
pm.plot_rays(rays, env=env, width=900)
# Out:
# BokehDeprecationWarning: 'asterisk() method' was deprecated in Bokeh 3.4.0 and will be removed, use "scatter(marker='asterisk', ...) instead" instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="ede5d66c-d9e3-4323-b063-2ccd87fc7862" data-root-id="p2905" style="display: contents;"></div>
